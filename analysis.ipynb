# %%
import numpy as np
import functions as func
import networkx as nx

# %% [markdown]
# ### Point 1

# %%
# The data of the edges from the text file
edgesData = func.getNetworkData("Alpha6Beta4Integrin-edges.txt")

# Initialize a graph with edges, name, and graph attributes
network = nx.DiGraph(name="PPI Network")

# Add given edges data to the network
network.add_weighted_edges_from(edgesData)

# Draw the given network 
func.drawNetworkGraph(network)

# %% [markdown]
# ### Point 2

# %%
# Get the shortest path(s) between the two given proteins
func.getShortestPaths(network,"Q16787","P24043")

# %% [markdown]
# ### Point 3

# %%
# The list of all proteins that are linked to a particular protein
func.getList(edgesData,"Q16787")

# %% [markdown]
# ### Point 4

# %%
# Create a histogram for a protein list
degrees= func.getDegreeAndHistogram(edgesData,["P23229","P00519","P31749","P42574"])


# Sort the list by the degree of its proteins
func.getOrderedDegree(degrees)

# %% [markdown]
# ### Point 5

# %%
# get tha Uniport IDs from text file
nodesData = func.getNodes("Alpha6Beta4Integrin-edges.txt")

func.convert_Uniport_to_gene_name(nodesData)
# Out:
# [{'from': 'Q05655', 'to': 'PRKCD'},
#  {'from': 'P08865', 'to': 'RPSA'},
#  {'from': 'O15230', 'to': 'LAMA5'},
#  {'from': 'Q92934', 'to': 'BAD'},
#  {'from': 'O95631', 'to': 'NTN1'},
#  {'from': 'P07942', 'to': 'LAMB1'},
#  {'from': 'Q9BST9', 'to': 'RTKN'},
#  {'from': 'Q04917', 'to': 'YWHAH'},
#  {'from': 'Q06124', 'to': 'PTPN11'},
#  {'from': 'P10275', 'to': 'AR'},
#  {'from': 'P42338', 'to': 'PIK3CB'},
#  {'from': 'P11047', 'to': 'LAMC1'},
#  {'from': 'P56537', 'to': 'EIF6'},
#  {'from': 'P48509', 'to': 'CD151'},
#  {'from': 'P12931', 'to': 'SRC'},
#  {'from': 'P08670', 'to': 'VIM'},
#  {'from': 'P25391', 'to': 'LAMA1'},
#  {'from': 'P15924', 'to': 'DSP'},
#  {'from': 'P35568', 'to': 'IRS1'},
#  {'from': 'Q03001', 'to': 'DST'},
#  {'from': 'P08581', 'to': 'MET'},
#  {'from': 'P62258', 'to': 'YWHAE'},
#  {'from': 'Q32MK0', 'to': 'MYLK3'},
#  {'from': 'A8K7I4', 'to': 'CLCA1'},
#  {'from': 'P48736', 'to': 'PIK3CG'},
#  {'from': 'P31749', 'to': 'AKT1'},
#  {'from': 'Q13153', 'to': 'PAK1'},
#  {'from': 'P63104', 'to': 'YWHAZ'},
#  {'from': 'P42336', 'to': 'PIK3CA'},
#  {'from': 'O15350', 'to': 'TP73'},
#  {'from': 'O00459', 'to': 'PIK3R2'},
#  {'from': 'P27348', 'to': 'YWHAQ'},
#  {'from': 'P07947', 'to': 'YES1'},
#  {'from': 'Q16787', 'to': 'LAMA3'},
#  {'from': 'Q15149', 'to': 'PLEC'},
#  {'from': 'Q13751', 'to': 'LAMB3'},
#  {'from': 'P23229', 'to': 'ITGA6'},
#  {'from': 'Q9UQC9', 'to': 'CLCA2'},
#  {'from': 'P31947', 'to': 'SFN'},
#  {'from': 'Q05397', 'to': 'PTK2'},
#  {'from': 'Q96RT1', 'to': 'ERBIN'},
#  {'from': 'Q13541', 'to': 'EIF4EBP1'},
#  {'from': 'Q9Y4H2', 'to': 'IRS2'},
#  {'from': 'P16144', 'to': 'ITGB4'},
#  {'from': 'P06730', 'to': 'EIF4E'},
#  {'from': 'P04626', 'to': 'ERBB2'},
#  {'from': 'P55268', 'to': 'LAMB2'},
#  {'from': 'P00533', 'to': 'EGFR'},
#  {'from': 'P00519', 'to': 'ABL1'},
#  {'from': 'Q04912', 'to': 'MST1R'},
#  {'from': 'P42574', 'to': 'CASP3'},
#  {'from': 'P27986', 'to': 'PIK3R1'},
#  {'from': 'P06241', 'to': 'FYN'},
#  {'from': 'P62993', 'to': 'GRB2'},
#  {'from': 'P17252', 'to': 'PRKCA'},
#  {'from': 'Q92569', 'to': 'PIK3R3'},
#  {'from': 'P31946', 'to': 'YWHAB'},
#  {'from': 'P29323', 'to': 'EPHB2'},
#  {'from': 'O00329', 'to': 'PIK3CD'},
#  {'from': 'P24043', 'to': 'LAMA2'},
#  {'from': 'P61586', 'to': 'RHOA'},
#  {'from': 'P42345', 'to': 'MTOR'},
#  {'from': 'P63000', 'to': 'RAC1'},
#  {'from': 'P29353', 'to': 'SHC1'},
#  {'from': 'Q13753', 'to': 'LAMC2'},
#  {'from': 'Q9UMD9', 'to': 'COL17A1'}]

# %% [markdown]
# ### Point 6

# %%
# get the egdes and nodes from the text file
edges = func.getEdges("Alpha6Beta4Integrin-edges.txt")
nodes = func.getNodes("Alpha6Beta4Integrin-edges.txt")

# generate the adjacency matrix
matrix = func.getAdjMatrix(nodes,edges)

# write the matrix in a text file
func.writeMatrixToTxt(matrix,nodes)
